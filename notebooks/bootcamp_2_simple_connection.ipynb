# %% [markdown]
# # Mini Spark Broker: Connection to the stream
#
# author: **Julien Peloton** [@JulienPeloton](https://github.com/JulienPeloton)
# Last Verifed to Run: 2019-02-04
#
# The purpose of this notebook is to connect the broker to the stream created by the LSST alert system.
#
# **Useful Links:**
#
# * https://spark.apache.org/docs/latest/structured-streaming-programming-guide.html
# * https://databricks.com/blog/2017/02/23/working-complex-data-formats-structured-streaming-apache-spark-2-1.html
# * https://databricks.com/blog/2016/07/28/structured-streaming-in-apache-spark.html
# * https://docs.databricks.com/_static/notebooks/structured-streaming-python.html
# * https://spark.apache.org/docs/2.2.0/structured-streaming-kafka-integration.html

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import window
from pyspark.sql import Row

import io
import gzip
import time

import aplpy
import fastavro
import numpy as np
from astropy.io import fits

import matplotlib
import matplotlib.pyplot as plt

from desc.msb import avroUtils
from desc.msb.filtering import make_dataframe_from_alerts
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Step 0: Running the LSST alert system
#
# In order to play with this notebook, you need to create the stream of alerts. see the README file of the bootcamp to set up your environment and launch the stream.

# %% [markdown]
# ## Step 1: Connecting to the stream with Apache Spark
#
# Once the stream is produced, let's initialise the Spark context:

# %%
# Grab the running Spark Session, 
# otherwise create it.
spark = SparkSession \
    .builder \
    .appName("firstConnection") \
    .getOrCreate()

# %% [markdown]
# Let's initialise a DataFrame that will read the stream from Kafka. Note that `kafka.bootstrap.servers` and `subscribe` must correspond to the arguments used for the LSST alert system (see above). At this point, we just create a Kafka Source for Streaming Queries - nothing really happens:

# %%
# Create a DF from the incoming stream from Kafka
# Note that <kafka.bootstrap.servers> and <subscribe>
# must correspond to arguments of the LSST alert system.
df = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "kafka:9092") \
  .option("subscribe", "ztf-stream") \
  .option("startingOffsets", "earliest") \
  .load()

df.isStreaming
# Out:
# True

# %% [markdown]
# As you can see, `df` is a streaming Dataframe. You can start streaming computation, by defining the sink and starting it.
# <!-- In our case, we want to interactively query the counts (same queries as above), so we will set the complete set of 1 hour counts to be in a in-memory table (note that this for testing purpose only in Spark 2.0). -->

# %% [markdown]
# ## Step 2: First interaction with the stream
#
# Let's see first if we can receive correctly alert packets. For this, we define a query to the stream that will just group alerts by publication date (window of 5 seconds):

# %%
# We group data by partitions, 
# and count the number of alerts per partition
# every 5 seconds.
streamingCountsDF = (
  df.groupBy(
      "partition", 
      window("timestamp", "5 seconds"))
    .count()
)

# %%
# keep the size of shuffles small
spark.conf.set("spark.sql.shuffle.partitions", "2")  

# Trigger the streaming computation, 
# by defining the sink (memory here) and starting it
countQuery = streamingCountsDF \
    .writeStream \
    .queryName("qcount")\
    .format("memory")\
    .outputMode("complete") \
    .start()

# %% [markdown]
# `qcount` is a handle to the streaming query that is running in the background. This query is continuously picking up alerts and updating the counts. Let's give a bit of time for the stream to update.

# %%
time.sleep(10)

# %% [markdown]
# You can easily access information about the progress in real-time:

# %%
countQuery.recentProgress
# Out:
# [{'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:13:57.280Z',
#   'batchId': 0,
#   'numInputRows': 366,
#   'processedRowsPerSecond': 36.806114239742556,
#   'durationMs': {'addBatch': 5157,
#    'getBatch': 110,
#    'getEndOffset': 1,
#    'queryPlanning': 639,
#    'setOffsetRange': 3833,
#    'triggerExecution': 9943,
#    'walCommit': 118},
#   'stateOperators': [{'numRowsTotal': 72,
#     'numRowsUpdated': 72,
#     'memoryUsedBytes': 15933,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 15645}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': None,
#     'endOffset': {'ztf-stream': {'0': 1364}},
#     'numInputRows': 366,
#     'processedRowsPerSecond': 36.806114239742556}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:07.256Z',
#   'batchId': 1,
#   'numInputRows': 7,
#   'inputRowsPerSecond': 0.7016840417000801,
#   'processedRowsPerSecond': 10.37037037037037,
#   'durationMs': {'addBatch': 449,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 76,
#    'setOffsetRange': 27,
#    'triggerExecution': 675,
#    'walCommit': 66},
#   'stateOperators': [{'numRowsTotal': 73,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 19861,
#     'customMetrics': {'loadedMapCacheHitCount': 4,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16365}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1364}},
#     'endOffset': {'ztf-stream': {'0': 1371}},
#     'numInputRows': 7,
#     'inputRowsPerSecond': 0.7016840417000801,
#     'processedRowsPerSecond': 10.37037037037037}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:07.933Z',
#   'batchId': 2,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 9,
#    'triggerExecution': 10},
#   'stateOperators': [{'numRowsTotal': 73,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 19861,
#     'customMetrics': {'loadedMapCacheHitCount': 4,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16365}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1371}},
#     'endOffset': {'ztf-stream': {'0': 1371}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:08.014Z',
#   'batchId': 2,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 52.631578947368425,
#   'processedRowsPerSecond': 1.3280212483399734,
#   'durationMs': {'addBatch': 534,
#    'getBatch': 2,
#    'getEndOffset': 0,
#    'queryPlanning': 101,
#    'setOffsetRange': 16,
#    'triggerExecution': 753,
#    'walCommit': 57},
#   'stateOperators': [{'numRowsTotal': 73,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20405,
#     'customMetrics': {'loadedMapCacheHitCount': 8,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16365}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1371}},
#     'endOffset': {'ztf-stream': {'0': 1372}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 52.631578947368425,
#     'processedRowsPerSecond': 1.3280212483399734}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:08.769Z',
#   'batchId': 3,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 1,
#    'setOffsetRange': 4,
#    'triggerExecution': 5},
#   'stateOperators': [{'numRowsTotal': 73,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20405,
#     'customMetrics': {'loadedMapCacheHitCount': 8,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16365}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1372}},
#     'endOffset': {'ztf-stream': {'0': 1372}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:09.035Z',
#   'batchId': 3,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 40.0,
#   'processedRowsPerSecond': 1.4492753623188408,
#   'durationMs': {'addBatch': 477,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 122,
#    'setOffsetRange': 4,
#    'triggerExecution': 690,
#    'walCommit': 57},
#   'stateOperators': [{'numRowsTotal': 73,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20405,
#     'customMetrics': {'loadedMapCacheHitCount': 12,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16365}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1372}},
#     'endOffset': {'ztf-stream': {'0': 1373}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 40.0,
#     'processedRowsPerSecond': 1.4492753623188408}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:09.726Z',
#   'batchId': 4,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 4,
#    'triggerExecution': 4},
#   'stateOperators': [{'numRowsTotal': 73,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20405,
#     'customMetrics': {'loadedMapCacheHitCount': 12,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16365}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1373}},
#     'endOffset': {'ztf-stream': {'0': 1373}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:10.027Z',
#   'batchId': 4,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 38.46153846153846,
#   'processedRowsPerSecond': 2.6666666666666665,
#   'durationMs': {'addBatch': 259,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 58,
#    'setOffsetRange': 6,
#    'triggerExecution': 375,
#    'walCommit': 29},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20541,
#     'customMetrics': {'loadedMapCacheHitCount': 16,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1373}},
#     'endOffset': {'ztf-stream': {'0': 1374}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 38.46153846153846,
#     'processedRowsPerSecond': 2.6666666666666665}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:10.403Z',
#   'batchId': 5,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 14,
#    'triggerExecution': 14},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20541,
#     'customMetrics': {'loadedMapCacheHitCount': 16,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1374}},
#     'endOffset': {'ztf-stream': {'0': 1374}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:11.022Z',
#   'batchId': 5,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 55.55555555555556,
#   'processedRowsPerSecond': 1.9646365422396856,
#   'durationMs': {'addBatch': 373,
#    'getBatch': 1,
#    'getEndOffset': 2,
#    'queryPlanning': 86,
#    'setOffsetRange': 4,
#    'triggerExecution': 509,
#    'walCommit': 24},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 20,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1374}},
#     'endOffset': {'ztf-stream': {'0': 1375}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 55.55555555555556,
#     'processedRowsPerSecond': 1.9646365422396856}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:11.532Z',
#   'batchId': 6,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 2,
#    'triggerExecution': 2},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 20,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1375}},
#     'endOffset': {'ztf-stream': {'0': 1375}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:12.028Z',
#   'batchId': 6,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 62.5,
#   'processedRowsPerSecond': 2.531645569620253,
#   'durationMs': {'addBatch': 273,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 58,
#    'setOffsetRange': 7,
#    'triggerExecution': 395,
#    'walCommit': 28},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 24,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1375}},
#     'endOffset': {'ztf-stream': {'0': 1376}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 62.5,
#     'processedRowsPerSecond': 2.531645569620253}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:12.423Z',
#   'batchId': 7,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 4,
#    'triggerExecution': 4},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 24,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1376}},
#     'endOffset': {'ztf-stream': {'0': 1376}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:13.026Z',
#   'batchId': 7,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 45.45454545454546,
#   'processedRowsPerSecond': 2.4937655860349124,
#   'durationMs': {'addBatch': 240,
#    'getBatch': 1,
#    'getEndOffset': 1,
#    'queryPlanning': 93,
#    'setOffsetRange': 3,
#    'triggerExecution': 401,
#    'walCommit': 29},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 28,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1376}},
#     'endOffset': {'ztf-stream': {'0': 1377}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 45.45454545454546,
#     'processedRowsPerSecond': 2.4937655860349124}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:13.428Z',
#   'batchId': 8,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 2,
#    'triggerExecution': 2},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 28,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1377}},
#     'endOffset': {'ztf-stream': {'0': 1377}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:14.024Z',
#   'batchId': 8,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 62.5,
#   'processedRowsPerSecond': 2.336448598130841,
#   'durationMs': {'addBatch': 311,
#    'getBatch': 0,
#    'getEndOffset': 2,
#    'queryPlanning': 62,
#    'setOffsetRange': 5,
#    'triggerExecution': 428,
#    'walCommit': 24},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 32,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1377}},
#     'endOffset': {'ztf-stream': {'0': 1378}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 62.5,
#     'processedRowsPerSecond': 2.336448598130841}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:14.453Z',
#   'batchId': 9,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 3,
#    'triggerExecution': 3},
#   'stateOperators': [{'numRowsTotal': 74,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20645,
#     'customMetrics': {'loadedMapCacheHitCount': 32,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16573}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1378}},
#     'endOffset': {'ztf-stream': {'0': 1378}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:15.028Z',
#   'batchId': 9,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 55.55555555555556,
#   'processedRowsPerSecond': 2.1645021645021645,
#   'durationMs': {'addBatch': 311,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 101,
#    'setOffsetRange': 6,
#    'triggerExecution': 462,
#    'walCommit': 25},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20781,
#     'customMetrics': {'loadedMapCacheHitCount': 36,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1378}},
#     'endOffset': {'ztf-stream': {'0': 1379}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 55.55555555555556,
#     'processedRowsPerSecond': 2.1645021645021645}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:15.491Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 2,
#    'triggerExecution': 2},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20781,
#     'customMetrics': {'loadedMapCacheHitCount': 36,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1379}},
#     'endOffset': {'ztf-stream': {'0': 1379}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:16.030Z',
#   'batchId': 10,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 62.5,
#   'processedRowsPerSecond': 1.6051364365971108,
#   'durationMs': {'addBatch': 469,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 91,
#    'setOffsetRange': 13,
#    'triggerExecution': 623,
#    'walCommit': 23},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 40,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1379}},
#     'endOffset': {'ztf-stream': {'0': 1380}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 62.5,
#     'processedRowsPerSecond': 1.6051364365971108}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:16.653Z',
#   'batchId': 11,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 3,
#    'triggerExecution': 4},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 40,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1380}},
#     'endOffset': {'ztf-stream': {'0': 1380}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:17.085Z',
#   'batchId': 11,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 35.714285714285715,
#   'processedRowsPerSecond': 2.638522427440633,
#   'durationMs': {'addBatch': 210,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 68,
#    'setOffsetRange': 3,
#    'triggerExecution': 379,
#    'walCommit': 79},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 44,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1380}},
#     'endOffset': {'ztf-stream': {'0': 1381}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 35.714285714285715,
#     'processedRowsPerSecond': 2.638522427440633}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:17.464Z',
#   'batchId': 12,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 3,
#    'triggerExecution': 3},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 44,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1381}},
#     'endOffset': {'ztf-stream': {'0': 1381}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:18.030Z',
#   'batchId': 12,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 47.61904761904761,
#   'processedRowsPerSecond': 3.2258064516129035,
#   'durationMs': {'addBatch': 202,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 66,
#    'setOffsetRange': 3,
#    'triggerExecution': 310,
#    'walCommit': 20},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 48,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1381}},
#     'endOffset': {'ztf-stream': {'0': 1382}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 47.61904761904761,
#     'processedRowsPerSecond': 3.2258064516129035}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:18.341Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 1,
#    'setOffsetRange': 1,
#    'triggerExecution': 2},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 48,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1382}},
#     'endOffset': {'ztf-stream': {'0': 1382}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:19.022Z',
#   'batchId': 13,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 66.66666666666667,
#   'processedRowsPerSecond': 2.6881720430107525,
#   'durationMs': {'addBatch': 241,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 72,
#    'setOffsetRange': 7,
#    'triggerExecution': 372,
#    'walCommit': 24},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 52,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1382}},
#     'endOffset': {'ztf-stream': {'0': 1383}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 66.66666666666667,
#     'processedRowsPerSecond': 2.6881720430107525}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:19.394Z',
#   'batchId': 14,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 2,
#    'triggerExecution': 2},
#   'stateOperators': [{'numRowsTotal': 75,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 20885,
#     'customMetrics': {'loadedMapCacheHitCount': 52,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16781}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1383}},
#     'endOffset': {'ztf-stream': {'0': 1383}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:20.035Z',
#   'batchId': 14,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 47.61904761904761,
#   'processedRowsPerSecond': 1.9646365422396856,
#   'durationMs': {'addBatch': 303,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 128,
#    'setOffsetRange': 3,
#    'triggerExecution': 509,
#    'walCommit': 49},
#   'stateOperators': [{'numRowsTotal': 76,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 21021,
#     'customMetrics': {'loadedMapCacheHitCount': 56,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16989}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1383}},
#     'endOffset': {'ztf-stream': {'0': 1384}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 47.61904761904761,
#     'processedRowsPerSecond': 1.9646365422396856}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:20.545Z',
#   'batchId': 15,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 2,
#    'triggerExecution': 2},
#   'stateOperators': [{'numRowsTotal': 76,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 21021,
#     'customMetrics': {'loadedMapCacheHitCount': 56,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 16989}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1384}},
#     'endOffset': {'ztf-stream': {'0': 1384}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:21.039Z',
#   'batchId': 15,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 40.0,
#   'processedRowsPerSecond': 2.277904328018223,
#   'durationMs': {'addBatch': 306,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 91,
#    'setOffsetRange': 2,
#    'triggerExecution': 439,
#    'walCommit': 16},
#   'stateOperators': [{'numRowsTotal': 76,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 21637,
#     'customMetrics': {'loadedMapCacheHitCount': 60,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 17501}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1384}},
#     'endOffset': {'ztf-stream': {'0': 1385}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 40.0,
#     'processedRowsPerSecond': 2.277904328018223}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:21.478Z',
#   'batchId': 16,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 3,
#    'triggerExecution': 3},
#   'stateOperators': [{'numRowsTotal': 76,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 21637,
#     'customMetrics': {'loadedMapCacheHitCount': 60,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 17501}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1385}},
#     'endOffset': {'ztf-stream': {'0': 1385}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:22.032Z',
#   'batchId': 16,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 66.66666666666667,
#   'processedRowsPerSecond': 2.7027027027027026,
#   'durationMs': {'addBatch': 255,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 60,
#    'setOffsetRange': 5,
#    'triggerExecution': 370,
#    'walCommit': 30},
#   'stateOperators': [{'numRowsTotal': 76,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 22149,
#     'customMetrics': {'loadedMapCacheHitCount': 64,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 17501}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1385}},
#     'endOffset': {'ztf-stream': {'0': 1386}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 66.66666666666667,
#     'processedRowsPerSecond': 2.7027027027027026}],
#   'sink': {'description': 'MemorySink'}},
#  {'id': 'a47b6cbc-30ed-46cc-883d-279218955056',
#   'runId': 'a96282a2-d92d-43f5-ab96-8f408fedbd38',
#   'name': 'qcount',
#   'timestamp': '2019-04-01T21:14:22.403Z',
#   'batchId': 17,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getEndOffset': 0,
#    'setOffsetRange': 1,
#    'triggerExecution': 1},
#   'stateOperators': [{'numRowsTotal': 76,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 22149,
#     'customMetrics': {'loadedMapCacheHitCount': 64,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 17501}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[ztf-stream]]',
#     'startOffset': {'ztf-stream': {'0': 1386}},
#     'endOffset': {'ztf-stream': {'0': 1386}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink'}}]

# %% [markdown]
# You can also use sql operations on the named in-memory query tables to create a classic DataFrame from the sink:

# %%
# Construct a DataFrame with time & number of alerts received by 
# window of 5 seconds
df_alert_count = spark.sql(
    """
    select 
        window.start as starting_utc_time, 
        window.end as ending_utc_time, 
        count as alerts_published 
    from 
        qcount 
    order by 
        ending_utc_time
    """
)

# Show the first rows of the DataFrame
df_alert_count.show()

# Count the number of alerts published so far
nalerts = df_alert_count.select("alerts_published").rdd.map(lambda x: x[0]).sum()
print("{} alerts published so far in the stream".format(nalerts))
# Out:
# +-------------------+-------------------+----------------+
# |  starting_utc_time|    ending_utc_time|alerts_published|
# +-------------------+-------------------+----------------+
# |2019-04-01 21:08:05|2019-04-01 21:08:10|               3|
# |2019-04-01 21:08:10|2019-04-01 21:08:15|               5|
# |2019-04-01 21:08:15|2019-04-01 21:08:20|               5|
# |2019-04-01 21:08:20|2019-04-01 21:08:25|               5|
# |2019-04-01 21:08:25|2019-04-01 21:08:30|               5|
# |2019-04-01 21:08:30|2019-04-01 21:08:35|               6|
# |2019-04-01 21:08:35|2019-04-01 21:08:40|               5|
# |2019-04-01 21:08:40|2019-04-01 21:08:45|               5|
# |2019-04-01 21:08:45|2019-04-01 21:08:50|               5|
# |2019-04-01 21:08:50|2019-04-01 21:08:55|               5|
# |2019-04-01 21:08:55|2019-04-01 21:09:00|               5|
# |2019-04-01 21:09:00|2019-04-01 21:09:05|               6|
# |2019-04-01 21:09:05|2019-04-01 21:09:10|               5|
# |2019-04-01 21:09:10|2019-04-01 21:09:15|               5|
# |2019-04-01 21:09:15|2019-04-01 21:09:20|               5|
# |2019-04-01 21:09:20|2019-04-01 21:09:25|               5|
# |2019-04-01 21:09:25|2019-04-01 21:09:30|               5|
# |2019-04-01 21:09:30|2019-04-01 21:09:35|               6|
# |2019-04-01 21:09:35|2019-04-01 21:09:40|               5|
# |2019-04-01 21:09:40|2019-04-01 21:09:45|               5|
# +-------------------+-------------------+----------------+
# only showing top 20 rows
#
# 430 alerts published so far in the stream

# %% [markdown]
# Note the columns `starting_time` and `ending_time` here correspond to the UTC times at which the alert has been published in Kafka (not the time at which you grab the alert).
#
# Below I plot the values collected after 3 full bursts of alerts sent at few hours interval:

# %%
matplotlib.rcParams.update({'font.size': 17})

# Go to Pandas world for plotting
pandas_df = df_alert_count.toPandas()

fig = plt.figure(figsize=(15, 5))
plt.plot(
    pandas_df["ending_utc_time"], 
    pandas_df["alerts_published"], 
    ls="", marker="o", color="C0")
plt.grid()

plt.ylim(0, pandas_df["alerts_published"].max() + 1)
plt.xlabel("Time UTC (DD HH:MM)")
plt.ylabel("Number of alerts published \n per 5 seconds window")

plt.gcf().autofmt_xdate()

fig = plt.figure(figsize=(15, 5))
plt.plot(
    pandas_df["ending_utc_time"], 
    np.cumsum(pandas_df["alerts_published"]), 
    ls="-", lw=2, color="C1")
plt.grid()

plt.xlabel("Time UTC (DD HH:MM)")
plt.ylabel("Number total of alerts published")

plt.gcf().autofmt_xdate()

# %% [markdown]
# Note that this corresponds to publication times. If you want to look at Spark performances, you can open the Spark UI and browse logs of jobs: http://localhost:400. In this simple example, Spark consumes all alerts in less than a second.

# %% [markdown]
# ## Step 4: Digging the alerts
#
# Now it is time to look at the alerts! The alert system encodes the alert in avro binary, so one needs to decode them.
# The way to decode the alert is to know its schema. We put a template alert in the folder `schemas` for convenience. Let's create a sink with the whole stream from Kafka, and access the alert through a DataFrame:

# %%
rawQuery = df\
    .writeStream \
    .queryName("qraw")\
    .format("memory")\
    .start()

# %%
# Give a bit of time for synchronisation
time.sleep(10)

# %%
# DataFrame
df_raw = spark.sql("select * from qraw")
df_raw.show(10)
# Out:
# +----+--------------------+----------+---------+------+--------------------+-------------+
# | key|               value|     topic|partition|offset|           timestamp|timestampType|
# +----+--------------------+----------+---------+------+--------------------+-------------+
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|   998|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|   999|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1000|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1001|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1002|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1003|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1004|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1005|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1006|2019-04-01 21:08:...|            0|
# |null|[06 33 2E 32 32 5...|ztf-stream|        0|  1007|2019-04-01 21:08:...|            0|
# +----+--------------------+----------+---------+------+--------------------+-------------+
# only showing top 10 rows

# %% [markdown]
# We can look closely at the columns of this Dataframe:

# %%
df_raw.printSchema()
df_raw.describe().show()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)
#
# +-------+----------+---------+------------------+-------------+
# |summary|     topic|partition|            offset|timestampType|
# +-------+----------+---------+------------------+-------------+
# |  count|       499|      499|               499|          499|
# |   mean|      null|      0.0|            1247.0|          0.0|
# | stddev|      null|      0.0|144.19315748906627|          0.0|
# |    min|ztf-stream|        0|               998|            0|
# |    max|ztf-stream|        0|              1496|            0|
# +-------+----------+---------+------------------+-------------+

# %% [markdown]
# The column of interest for us is `value` which contains the alert data. For the moment, the data is `binary`, so let's decode it. First read the corresponding schema (ZTF in this example):

# %%
# Read the schema
alert_schema = avroUtils.readSchemaFromAvroFile("../schemas/template_schema_ZTF.avro")

# Broadcast the schema to all Spark executors
# (Keep in mind we work in a distributed environment!)
sc.broadcast(alert_schema)

# Look at the available keys
print(alert_schema.keys())
# Out:
# dict_keys(['type', 'version', 'name', 'namespace', 'fields', 'doc'])

# %% [markdown]
# Now we have the schema, we can decode the alerts. For technical reason, you need to go to RDD world to use in a meaningful way the decoder:

# %%
# RDD: Resilient Distributed Dataset.
# Both Spark DataFrames and RDDs are distributed memory abstractions, fault-tolerant and immutable.
# The main difference is that Dataframes are organized into named columns with defined 
# data types and including the benefits of Spark SQL's execution engine.
# Historically, there were only RDDs. DataFrame came later in Spark.
rdd_alerts = df_raw.select("value").rdd.map(lambda x: avroUtils.decoder(x.value, alert_schema))

# %% [markdown]
# And here is one full alert:

# %%
rdd_alerts.take(1)
# Out:
# [{'schemavsn': '3.2',
#   'publisher': 'ZTF (www.ztf.caltech.edu)',
#   'objectId': 'ZTF18abyouwp',
#   'candid': 697251920015010010,
#   'candidate': {'jd': 2458451.7519213,
#    'fid': 1,
#    'pid': 697251920015,
#    'diffmaglim': 19.647123336791992,
#    'pdiffimfilename': 'ztf_20181129251771_000248_zg_c01_o_q1_scimrefdiffimg.fits',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': 697251920015010010,
#    'isdiffpos': 'f',
#    'tblid': 10,
#    'nid': 697,
#    'rcid': 0,
#    'field': 248,
#    'xpos': 1817.9852294921875,
#    'ypos': 2753.298828125,
#    'ra': 26.8566983,
#    'dec': -26.9677112,
#    'magpsf': 14.283452987670898,
#    'sigmapsf': 0.038736678659915924,
#    'chipsf': 50.48195266723633,
#    'magap': 14.340100288391113,
#    'sigmagap': 0.008100000210106373,
#    'distnr': 0.24791085720062256,
#    'magnr': 12.048999786376953,
#    'sigmagnr': 0.012000000104308128,
#    'chinr': 0.6589999794960022,
#    'sharpnr': 0.032999999821186066,
#    'sky': 0.5009307861328125,
#    'magdiff': 0.05664699897170067,
#    'fwhm': 2.3299999237060547,
#    'classtar': 0.8769999742507935,
#    'mindtoedge': 327.20111083984375,
#    'magfromlim': 5.307022571563721,
#    'seeratio': 1.3288816213607788,
#    'aimage': 0.9580000042915344,
#    'bimage': 0.8809999823570251,
#    'aimagerat': 0.41115880012512207,
#    'bimagerat': 0.3781116008758545,
#    'elong': 1.0874006748199463,
#    'nneg': 0,
#    'nbad': 0,
#    'rb': 0.6100000143051147,
#    'ssdistnr': -999.0,
#    'ssmagnr': -999.0,
#    'ssnamenr': 'null',
#    'sumrat': 1.0,
#    'magapbig': 14.338600158691406,
#    'sigmagapbig': 0.00839999970048666,
#    'ranr': 26.8566499,
#    'decnr': -26.967766,
#    'sgmag1': 11.918000221252441,
#    'srmag1': 10.45300006866455,
#    'simag1': 9.729000091552734,
#    'szmag1': 9.267000198364258,
#    'sgscore1': 0.5,
#    'distpsnr1': 0.1676003485918045,
#    'ndethist': 4,
#    'ncovhist': 38,
#    'jdstarthist': 2458384.8985301,
#    'jdendhist': 2458451.7519213,
#    'scorr': 8.89216804504395,
#    'tooflag': 0,
#    'objectidps1': 75630268567608995,
#    'objectidps2': 75630268562768847,
#    'sgmag2': 12.23799991607666,
#    'srmag2': 10.881500244140625,
#    'simag2': -999.0,
#    'szmag2': 9.437250137329102,
#    'sgscore2': 0.5,
#    'distpsnr2': 0.3954409062862396,
#    'objectidps3': 75630268563979163,
#    'sgmag3': 12.601499557495117,
#    'srmag3': 12.199999809265137,
#    'simag3': 9.800970077514648,
#    'szmag3': 9.463669776916504,
#    'sgscore3': 0.5,
#    'distpsnr3': 1.3741188049316406,
#    'nmtchps': 13,
#    'rfid': 248120100,
#    'jdstartref': 2458347.978472,
#    'jdendref': 2458377.856551,
#    'nframesref': 16,
#    'rbversion': 't8_f5_c3',
#    'dsnrms': 282.881103515625,
#    'ssnrms': 970.205322265625,
#    'dsdiff': -687.32421875,
#    'magzpsci': 25.40245246887207,
#    'magzpsciunc': 4.0740698750596493e-05,
#    'magzpscirms': 0.044110000133514404,
#    'nmatches': 234,
#    'clrcoeff': -0.0569549985229969,
#    'clrcounc': 6.917359860381112e-05,
#    'zpclrcov': -4.836000152863562e-05,
#    'zpmed': 25.367000579833984,
#    'clrmed': 0.5920000076293945,
#    'clrrms': 0.31644099950790405,
#    'neargaia': 0.24275486171245575,
#    'neargaiabright': 0.24275486171245575,
#    'maggaia': 10.286620140075684,
#    'maggaiabright': 10.286620140075684,
#    'exptime': 30.0},
#   'prv_candidates': [{'jd': 2458422.8142593,
#     'fid': 2,
#     'pid': 668314250015,
#     'diffmaglim': 19.058900833129883,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1031/314109/ztf_20181031314109_000248_zr_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 668,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458425.8351389,
#     'fid': 1,
#     'pid': 671335130015,
#     'diffmaglim': 19.371599197387695,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1103/334965/ztf_20181103334965_000248_zg_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 671,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458428.7509954,
#     'fid': 2,
#     'pid': 674250990015,
#     'diffmaglim': 19.78499984741211,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1106/250880/ztf_20181106250880_000248_zr_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 674,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458428.7935532,
#     'fid': 1,
#     'pid': 674293550015,
#     'diffmaglim': 20.048099517822266,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1106/293403/ztf_20181106293403_000248_zg_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 674,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458431.7310301,
#     'fid': 1,
#     'pid': 677231030015,
#     'diffmaglim': 19.156299591064453,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1109/231030/ztf_20181109231030_000248_zg_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 677,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458431.7725347,
#     'fid': 2,
#     'pid': 677272530015,
#     'diffmaglim': 18.49250030517578,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1109/272373/ztf_20181109272373_000248_zr_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 677,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458434.7938889,
#     'fid': 2,
#     'pid': 680293880015,
#     'diffmaglim': 19.113300323486328,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1112/293877/ztf_20181112293877_000248_zr_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 680,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458437.7298727,
#     'fid': 1,
#     'pid': 683229870015,
#     'diffmaglim': 19.508699417114258,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1115/229711/ztf_20181115229711_000248_zg_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': 683229870015015004,
#     'isdiffpos': 't',
#     'tblid': 4,
#     'nid': 683,
#     'rcid': 0,
#     'field': 248,
#     'xpos': 1813.0899658203125,
#     'ypos': 2749.669921875,
#     'ra': 26.8570275,
#     'dec': -26.9678339,
#     'magpsf': 15.45419979095459,
#     'sigmapsf': 0.05859300121665001,
#     'chipsf': 16.585399627685547,
#     'magap': 15.307499885559082,
#     'sigmagap': 0.015799999237060547,
#     'distnr': 1.2203999757766724,
#     'magnr': 12.048999786376953,
#     'sigmagnr': 0.012000000104308128,
#     'chinr': 0.6589999794960022,
#     'sharpnr': 0.032999999821186066,
#     'sky': 0.4363749921321869,
#     'magdiff': -0.14670300483703613,
#     'fwhm': 1.9213099479675293,
#     'classtar': 0.9929999709129333,
#     'mindtoedge': 330.8269958496094,
#     'magfromlim': 4.201159954071045,
#     'seeratio': 2.0,
#     'aimage': 0.9200000166893005,
#     'bimage': 0.7749999761581421,
#     'aimagerat': 0.4788390100002289,
#     'bimagerat': 0.4033699929714203,
#     'elong': 1.1871000528335571,
#     'nneg': 1,
#     'nbad': 0,
#     'rb': 0.5166670083999634,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': 1.0,
#     'magapbig': 15.270299911499023,
#     'sigmagapbig': 0.01600000075995922,
#     'ranr': 26.8566499,
#     'decnr': -26.967766,
#     'scorr': 8.79511,
#     'rbversion': 't12_f5_c3'},
#    {'jd': 2458437.7717477,
#     'fid': 2,
#     'pid': 683271740015,
#     'diffmaglim': 19.34830093383789,
#     'pdiffimfilename': '/ztf/archive/sci/2018/1115/271609/ztf_20181115271609_000248_zr_c01_o_q1_scimrefdiffimg.fits.fz',
#     'programpi': 'Kulkarni',
#     'programid': 1,
#     'candid': None,
#     'isdiffpos': None,
#     'tblid': None,
#     'nid': 683,
#     'rcid': 0,
#     'field': 248,
#     'xpos': None,
#     'ypos': None,
#     'ra': None,
#     'dec': None,
#     'magpsf': None,
#     'sigmapsf': None,
#     'chipsf': None,
#     'magap': None,
#     'sigmagap': None,
#     'distnr': None,
#     'magnr': None,
#     'sigmagnr': None,
#     'chinr': None,
#     'sharpnr': None,
#     'sky': None,
#     'magdiff': None,
#     'fwhm': None,
#     'classtar': None,
#     'mindtoedge': None,
#     'magfromlim': None,
#     'seeratio': None,
#     'aimage': None,
#     'bimage': None,
#     'aimagerat': None,
#     'bimagerat': None,
#     'elong': None,
#     'nneg': None,
#     'nbad': None,
#     'rb': None,
#     'ssdistnr': None,
#     'ssmagnr': None,
#     'ssnamenr': None,
#     'sumrat': None,
#     'magapbig': None,
#     'sigmagapbig': None,
#     'ranr': None,
#     'decnr': None,
#     'scorr': None,
#     'rbversion': 't12_f5_c3'}],
#   'cutoutScience': {'fileName': 'candid697251920015010010_pid697251920015_targ_sci.fits.gz',
#    'stampData': b'\x1f\x8b\x08\x00`\x92\xff[\x02\x03\xed\x9bUx\xd5\xd7\xff\xa5)\x0eE\x82\xbbSJ\xb1\xe2\xa58o\x12\xacXB\x02\xc4\xdd\xe5\xe4\xb8\xe4\xb8\xe7D\t\x16\\\x1a\xdc\xdd\xa5\xb8kp\xd7\x02\xc5\xdd\x99\xfd\xfb\xcf\xdd<s33\xffg\xae\xba\xef\xc8I\xf69\xdf\xbd?k\xadw\x85\'c\x87\x8d\x1c3\xc2\xb7y\xf3~\xcd\x9b\x074\xffoX\x0c\x0b\x183l\xc2\x7f\xed\xf7\xbf\xae\x8e\xdd\xba\xfe\x9f\xef7j\xd0\x84ac\x9b\xffo\xf7k\xde\xfc\xffv\xbf.\xff\xfb\xfdzv\xfb\xbf\xdc\xaf\xeb\x7f\xdf~\x04\x8e\x1a\x16\xf0_\xcf\xfb\xb3\xcf\xa8\xff\xf9\xa5\x9f\xff_\xee\xc3w\x94O\xf3\x7f\xd7\xbf\xeb\xdf\xf5\xef\xfaw\xfd\xbb\xfe]\xff\xae\x7f\xd7\x7f\xdf\xc2ZO\x87\xc5SLf\x85Dbj\xadCr\x00"l\x91h\xae\x14\xa3\x18P\nw\xef\xb5\xa4,\x1d\x8cf\xe1I\x92g-@\x11\x9b\x8a\xbbb+4\xb5\x14\x8c\xbe\xbe\x0cw\xdd\xd5d\xbc\x9e\x87\xfb\x
a\xa4\xc0\xe14\xb0b+~\x81\xbb\xf6|\xb4\xb7\xd8\x08*\xbd1\x8cR\xd9eV\xc1\xe9-\xbd\xb3)\x91\xbeK\t\xc2\x8a\xc8\xb3Pwk\x1a\xcb\x1fc\xcc\xec\tt\xc6\xcf\x0bt0Df\x84\xdb\x9aD\xf0b\x88\x14\x96\xdf*\xaf\xfaa0\x97p9\'H\xea\xce\x15\xe01\xab\n\x04\xd4v\x90O\xf5\xd7\x88\xcb\x0e)X\xa5\x14\r\x13\xbb$Y\xe1\x90\x9d \xfa6\x11\xb4n\x0f\xc0\xce\x1fg\xd0\xb5;\x02j\xca\x1e\x98\xcd\xdd\x84\xb0!\xe9\x01\xfd\xc2YI\xb7\x0b\xbd\xc4C^\x85\xd4\xe83@\x84e/\xa9P*\xa8\xda\x90j\xc6\nL\x9f\x85\xdb\x0fT\x91\xe6\x1ds\xb97\x85C\xe8\xbdS\x06`\xb6\xa7\x06~\xc96\xb2\xda\x1e\x9b\x89\xf9\xad\xf5\xf04|\x9c\x8d\x959f\xb6H\xa7\n\xaa\xd5\xef\xa0Hy\t\xaa8\x8a\xe2\xd2\xea\xabX\xdd\xe9F6k\xcaABT5h.8\n/\xc3R\xcc\xe2_\xfed\x94\xcd\xbb!\xa8{\x9c\x86\xe8w\x9ai\xcc\xe1!Q{\xf3\x19\x9e\xcd\xc2t\xf7cux\xa7\xb1\x14/\x0c/C\xf5\xb8\x02B>x\xa0\xd5\xdc\x1a\xd2\xa32\xc6\xc8\xed~\x88\xae\xc2o\x18\x11\xc5\xadXf\xa7\x87\x97l\xf4\xc0\xb5\xf6,\xe5\xf4\x9d\xc6^\xc5\x15\xe0\x1b\x94\rZ\x9ccDO{\x18\x17\x9b\xd8\xa1\xc3\xc2h\xc8M\x93C\xbbZ9\xbag\xa0\rkT\xe6\x82\xcd^azt\xcbW\xbc\xd9.\x0f\x7fn\xc8\xe3\xb1\x00W4]\xdc\x82\x85\xfcSh\xd7GAFo\x87/X\x9bK\x13\x0fp"Y\x029\xf4\xbb\xd10\x145\xafe\xe4\xdf\xf6\xd2\xe6\xaf\xc0\x19#7\x18\x91\xeb\x94\xd ...

# %% [markdown]
# One could convert this RDD back to DataFrame, but the schema of the alerts is nested, which can lead to trouble.
# Instead, let's see what are the keys we have in the alert:

# %%
rdd_alerts.map(lambda x: [ (i, type(j)) for i, j in zip(x.keys(), x.values())]).take(1)
# Out:
# [[('schemavsn', str),
#   ('publisher', str),
#   ('objectId', str),
#   ('candid', int),
#   ('candidate', dict),
#   ('prv_candidates', list),
#   ('cutoutScience', dict),
#   ('cutoutTemplate', dict),
#   ('cutoutDifference', dict)]]

# %% [markdown]
# ### Candidate
#
# The entry candidate is a simple `dict` that can be transformed into a standalone DataFrame:

# %%
# Go from RDD to Dataframe
df_alerts = rdd_alerts.map(lambda x: Row(**x["candidate"])).toDF()

# Look at the schema
df_alerts.printSchema()
# Out:
# root
#  |-- aimage: double (nullable = true)
#  |-- aimagerat: double (nullable = true)
#  |-- bimage: double (nullable = true)
#  |-- bimagerat: double (nullable = true)
#  |-- candid: long (nullable = true)
#  |-- chinr: double (nullable = true)
#  |-- chipsf: double (nullable = true)
#  |-- classtar: double (nullable = true)
#  |-- clrcoeff: double (nullable = true)
#  |-- clrcounc: double (nullable = true)
#  |-- clrmed: double (nullable = true)
#  |-- clrrms: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- decnr: double (nullable = true)
#  |-- diffmaglim: double (nullable = true)
#  |-- distnr: double (nullable = true)
#  |-- distpsnr1: double (nullable = true)
#  |-- distpsnr2: double (nullable = true)
#  |-- distpsnr3: double (nullable = true)
#  |-- dsdiff: double (nullable = true)
#  |-- dsnrms: double (nullable = true)
#  |-- elong: double (nullable = true)
#  |-- exptime: double (nullable = true)
#  |-- fid: long (nullable = true)
#  |-- field: long (nullable = true)
#  |-- fwhm: double (nullable = true)
#  |-- isdiffpos: string (nullable = true)
#  |-- jd: double (nullable = true)
#  |-- jdendhist: double (nullable = true)
#  |-- jdendref: double (nullable = true)
#  |-- jdstarthist: double (nullable = true)
#  |-- jdstartref: double (nullable = true)
#  |-- magap: double (nullable = true)
#  |-- magapbig: double (nullable = true)
#  |-- magdiff: double (nullable = true)
#  |-- magfromlim: double (nullable = true)
#  |-- maggaia: double (nullable = true)
#  |-- maggaiabright: double (nullable = true)
#  |-- magnr: double (nullable = true)
#  |-- magpsf: double (nullable = true)
#  |-- magzpsci: double (nullable = true)
#  |-- magzpscirms: double (nullable = true)
#  |-- magzpsciunc: double (nullable = true)
#  |-- mindtoedge: double (nullable = true)
#  |-- nbad: long (nullable = true)
#  |-- ncovhist: long (nullable = true)
#  |-- ndethist: long (nullable = true)
#  |-- neargaia: double (nullable = true)
#  |-- neargaiabright: double (nullable = true)
#  |-- nframesref: long (nullable = true)
#  |-- nid: long (nullable = true)
#  |-- nmatches: long (nullable = true)
#  |-- nmtchps: long (nullable = true)
#  |-- nneg: long (nullable = true)
#  |-- objectidps1: long (nullable = true)
#  |-- objectidps2: long (nullable = true)
#  |-- objectidps3: long (nullable = true)
#  |-- pdiffimfilename: string (nullable = true)
#  |-- pid: long (nullable = true)
#  |-- programid: long (nullable = true)
#  |-- programpi: string (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- ranr: double (nullable = true)
#  |-- rb: double (nullable = true)
#  |-- rbversion: string (nullable = true)
#  |-- rcid: long (nullable = true)
#  |-- rfid: long (nullable = true)
#  |-- scorr: double (nullable = true)
#  |-- seeratio: double (nullable = true)
#  |-- sgmag1: double (nullable = true)
#  |-- sgmag2: double (nullable = true)
#  |-- sgmag3: double (nullable = true)
#  |-- sgscore1: double (nullable = true)
#  |-- sgscore2: double (nullable = true)
#  |-- sgscore3: double (nullable = true)
#  |-- sharpnr: double (nullable = true)
#  |-- sigmagap: double (nullable = true)
#  |-- sigmagapbig: double (nullable = true)
#  |-- sigmagnr: double (nullable = true)
#  |-- sigmapsf: double (nullable = true)
#  |-- simag1: double (nullable = true)
#  |-- simag2: double (nullable = true)
#  |-- simag3: double (nullable = true)
#  |-- sky: double (nullable = true)
#  |-- srmag1: double (nullable = true)
#  |-- srmag2: double (nullable = true)
#  |-- srmag3: double (nullable = true)
#  |-- ssdistnr: double (nullable = true)
#  |-- ssmagnr: double (nullable = true)
#  |-- ssnamenr: string (nullable = true)
#  |-- ssnrms: double (nullable = true)
#  |-- sumrat: double (nullable = true)
#  |-- szmag1: double (nullable = true)
#  |-- szmag2: double (nullable = true)
#  |-- szmag3: double (nullable = true)
#  |-- tblid: long (nullable = true)
#  |-- tooflag: long (nullable = true)
#  |-- xpos: double (nullable = true)
#  |-- ypos: double (nullable = true)
#  |-- zpclrcov: double (nullable = true)
#  |-- zpmed: double (nullable = true)

# %% [markdown]
# You can easily select all the values for a subset of columns, e.g.

# %%
colnames = ["ra", "dec", "fwhm", "candid","nbad"]
df_alerts.select(colnames).show()
# Out:
# +----------+-----------+------------------+------------------+----+
# |        ra|        dec|              fwhm|            candid|nbad|
# +----------+-----------+------------------+------------------+----+
# |26.8566983|-26.9677112|2.3299999237060547|697251920015010010|   0|
# |  26.24497|-26.7569436|1.5973387956619263|697251920115015007|   0|
# |26.1126147|-26.8053928|1.5973387956619263|697251920115015008|   0|
# |25.5844032|-27.9239037|1.5603374242782593|697251920215010008|   0|
# |25.5902591|-27.9131274|1.5603374242782593|697251920215010010|   0|
# |26.0145383|-27.9003972|1.5603374242782593|697251920215010011|   0|
# |25.6648433|-27.8417869|1.5603374242782593|697251920215010013|   0|
# |24.4538066|-27.0766656|1.7182927131652832|697251920415010000|   0|
# |24.9350326|-26.5438418|3.7100000381469727|697251920415015001|   0|
# | 23.517342|-27.0446981| 1.781453013420105|697251920515010004|   0|
# | 23.439535|-26.9757725| 1.781453013420105|697251920515010007|   0|
# |23.5013762|-26.9553962| 1.781453013420105|697251920515010009|   0|
# |23.4996432|-26.8807163| 1.781453013420105|697251920515010011|   0|
# |23.9507731|-26.8155047| 3.200000047683716|697251920515015005|   0|
# |23.4351002|-27.7295763|1.7016726732254028|697251920615010004|   0|
# |24.1275399|-27.1943727|1.7016726732254028|697251920615015001|   0|
# |24.3410417|-27.2283478|1.7016726732254028|697251920615015002|   0|
# | 23.474041|-27.2662801|1.7016726732254028|697251920615015003|   0|
# |25.2947531|   -27.9534|    1.628662109375|697251920715010005|   0|
# | 24.528236|-27.8325121|    1.628662109375|697251920715010010|   0|
# +----------+-----------+------------------+------------------+----+
# only showing top 20 rows

# %% [markdown]
# ### Cutout
#
# The `cutout*` entries contain square images around the position of the alert. Let's have a look at a few of those:

# %%
def plot_cutout(stamp, fig=None, subplot=None, **kwargs):
    """ Plot square FITS image stores in the ZTF alert.
    Borrowed from the ZTF repo: 
    https://github.com/ZwickyTransientFacility/ztf-avro-alert/
    
    Parameters
    ----------
    stamp: bytes
        Binary image data
        
    Returns
    ----------
    ffig: FITSFigure
    """
    with gzip.open(io.BytesIO(stamp), 'rb') as f:
        with fits.open(io.BytesIO(f.read())) as hdul:
            if fig is None:
                fig = plt.figure(figsize=(4,4))
            if subplot is None:
                subplot = (1,1,1)
            ffig = aplpy.FITSFigure(
                hdul[0], figure=fig, subplot=subplot, **kwargs)
            ffig.show_grayscale(stretch='arcsinh')
    return ffig

# %%
# Take a few alerts
alerts = rdd_alerts.take(3)

fig = plt.figure(figsize=(10, 10))
for index_alert, alert in enumerate(alerts):
    for index_cutout, cutout in enumerate(
            ["cutoutScience", "cutoutTemplate", "cutoutDifference"]):
        o = plot_cutout(
            alert[cutout]["stampData"], 
            fig=fig, subplot=(3, 3, 3*index_alert+index_cutout+1))
        if index_alert == 0:
            o.set_title(cutout)
        if index_cutout == 0:
            o.add_label(30, 5, "{}".format(alert["objectId"]), color="white")
# Out:
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  4.893e+01 [aplpy.core]
# INFO: Auto-setting vmax to  6.019e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  6.044e+01 [aplpy.core]
# INFO: Auto-setting vmax to  6.376e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to -1.458e+01 [aplpy.core]
# INFO: Auto-setting vmax to  9.382e+02 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  5.310e+01 [aplpy.core]
# INFO: Auto-setting vmax to  2.278e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  6.599e+01 [aplpy.core]
# INFO: Auto-setting vmax to  1.974e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to -4.783e+01 [aplpy.core]
# INFO: Auto-setting vmax to  3.903e+01 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  5.392e+01 [aplpy.core]
# INFO: Auto-setting vmax to  3.730e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  6.602e+01 [aplpy.core]
# INFO: Auto-setting vmax to  3.188e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to -4.768e+01 [aplpy.core]
# INFO: Auto-setting vmax to  7.262e+01 [aplpy.core]

# %% [markdown]
# ### Alternative to quickly create DataFrames
#
# You can also select a few entries of interest from the full alert, and make a DataFrame out of those:

# %%
def myEntries(dic):
    """ Returns only tuple of values from a dictionary
    
    Parameters
    ----------
    dic: dict
        Python dictionary (the alert)
        
    Returns
    ----------
    out: tuple of values
    """
    ID = dic["objectId"]
    ra = dic["candidate"]["ra"]
    dec = dic["candidate"]["dec"]
    imdiff = dic["prv_candidates"][0]["pdiffimfilename"]
    
    return (ID, ra, dec, imdiff)

mydf = rdd_alerts.map(myEntries).toDF(["ID", "RA", "DEC", "pdiffimfilename"])
mydf.show()
# Out:
# +------------+----------+-----------+--------------------+
# |          ID|        RA|        DEC|     pdiffimfilename|
# +------------+----------+-----------+--------------------+
# |ZTF18abyouwp|26.8566983|-26.9677112|/ztf/archive/sci/...|
# |ZTF18acsbjqe|  26.24497|-26.7569436|/ztf/archive/sci/...|
# |ZTF18acaixum|26.1126147|-26.8053928|/ztf/archive/sci/...|
# |ZTF18acsbjqg|25.5844032|-27.9239037|/ztf/archive/sci/...|
# |ZTF18acsbjqi|25.5902591|-27.9131274|/ztf/archive/sci/...|
# |ZTF18acsbjqf|26.0145383|-27.9003972|/ztf/archive/sci/...|
# |ZTF18acsbjqh|25.6648433|-27.8417869|/ztf/archive/sci/...|
# |ZTF18acsbjou|24.4538066|-27.0766656|/ztf/archive/sci/...|
# |ZTF18abvdmcb|24.9350326|-26.5438418|/ztf/archive/sci/...|
# |ZTF18acsbjpf| 23.517342|-27.0446981|/ztf/archive/sci/...|
# |ZTF18acsbjpe| 23.439535|-26.9757725|/ztf/archive/sci/...|
# |ZTF18acsbjpg|23.5013762|-26.9553962|/ztf/archive/sci/...|
# |ZTF18acsbjph|23.4996432|-26.8807163|/ztf/archive/sci/...|
# |ZTF18abvrcws|23.9507731|-26.8155047|/ztf/archive/sci/...|
# |ZTF18abvryvj|23.4351002|-27.7295763|/ztf/archive/sci/...|
# |ZTF18abvlvll|24.1275399|-27.1943727|/ztf/archive/sci/...|
# |ZTF18abvlvlm|24.3410417|-27.2283478|/ztf/archive/sci/...|
# |ZTF18abvryyt| 23.474041|-27.2662801|/ztf/archive/sci/...|
# |ZTF18acsbjox|25.2947531|   -27.9534|/ztf/archive/sci/...|
# |ZTF18acsbjoy| 24.528236|-27.8325121|/ztf/archive/sci/...|
# +------------+----------+-----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Or from nested dictionaries:

# %%
colnames = [
    "objectId", "candidate:ra",
    "candidate:dec"
]
mydf2 = make_dataframe_from_alerts(rdd_alerts, colnames)
mydf2.show()
# Out:
# +------------+------------+-------------+
# |    objectId|candidate:ra|candidate:dec|
# +------------+------------+-------------+
# |ZTF18abyouwp|  26.8566983|  -26.9677112|
# |ZTF18acsbjqe|    26.24497|  -26.7569436|
# |ZTF18acaixum|  26.1126147|  -26.8053928|
# |ZTF18acsbjqg|  25.5844032|  -27.9239037|
# |ZTF18acsbjqi|  25.5902591|  -27.9131274|
# |ZTF18acsbjqf|  26.0145383|  -27.9003972|
# |ZTF18acsbjqh|  25.6648433|  -27.8417869|
# |ZTF18acsbjou|  24.4538066|  -27.0766656|
# |ZTF18abvdmcb|  24.9350326|  -26.5438418|
# |ZTF18acsbjpf|   23.517342|  -27.0446981|
# |ZTF18acsbjpe|   23.439535|  -26.9757725|
# |ZTF18acsbjpg|  23.5013762|  -26.9553962|
# |ZTF18acsbjph|  23.4996432|  -26.8807163|
# |ZTF18abvrcws|  23.9507731|  -26.8155047|
# |ZTF18abvryvj|  23.4351002|  -27.7295763|
# |ZTF18abvlvll|  24.1275399|  -27.1943727|
# |ZTF18abvlvlm|  24.3410417|  -27.2283478|
# |ZTF18abvryyt|   23.474041|  -27.2662801|
# |ZTF18acsbjox|  25.2947531|     -27.9534|
# |ZTF18acsbjoy|   24.528236|  -27.8325121|
# +------------+------------+-------------+
# only showing top 20 rows
